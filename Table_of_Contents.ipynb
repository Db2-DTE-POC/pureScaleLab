# %% [markdown]
# ![Logo](images/c2c-logo.jpg#left)

# %% [markdown]
# # Db2 Click to Containerize Lab
# These series of notebooks will demonstrate how to install Db2U on a Kubernetes cluster and then use the Db2 Shift utility to move an on-premise database into a Db2U Pod.

# %% [markdown]
# <!-- Row 0 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Introduction to Jupyter Notebooks
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# If you are not familiar with Jupyter notebooks, select this document to learn about the basics of navigating within a notebook.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./An_Introduction_to_Jupyter_Notebooks.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Introduction to the Lab
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# What exactly are you going to do in the lab and what makes up this environment? Start here to find out what the lab is all about.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2Shift_Lab.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Db2 Shift
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Db2 Shift is the name of the utility that allows for the easy movement of your Db2 database into a containerized (or virtual machine) environment. This document gives you an overview of the utility and the features that it includes.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2_Shift.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>
#
# <!-- Row 1 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Kubernetes, the Db2 Operator, and Db2U
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Before you begin shifting a database, you will need a Kubernetes environment! This lab takes you through the steps required to get the Db2 Operator installed and then provision a Db2U pod. Once this environment is running you will be able to start shifting your Db2 databases!
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./DB2U_Installation.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Kubernetes Console (Optional)
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# If you have the time, you can try out the Kubernetes console. This console will allow you to explore the various Pods and services that are running the Kubernetes cluster. You can also use the console to examine the Db2 POD and shell into the environment to check the database status.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Kubernetes_Console.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Terminal Basics
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# The lab exercises requires that you connect to multiple machines. Rather than using a console on each physical machine, this section will explain how you can open up a terminal window and use that to issues commands on the servers.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Terminal.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# <!-- Row 2 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Shift Db2 to Db2U
#         </div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Description -->
# The most common type of shift involves moving a traditional Db2 database into a Kubernetes, OpenShift, or Cloud Pak for Data Environment. This lab will move a Db2 11.5 database into a Db2U POD running on Kubernetes.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2_Db2u.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Clone Db2 and Deploy to Db2U
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Air-gapped environments prevent the shift of a database directly from source to target. The Db2 Shift clone option will make a copy of the database which can be used at the target location as the source database.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2_Db2u_Clone.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Shift and Upgrade Db2 11.1 to Db2U
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# The Db2 Shift command will automatically upgrade your database from 10.5 and 11.1 to the latest version of Db2 in a container (currently 11.5.8). This shift scenario will take you through the steps of shifting and upgrading an existing database.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2_Upgrade.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# <!-- Row 3 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Db2 to Db2 with HADR Connection
#         </div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Description -->
# One option when shifting a database is to make the new copy an HADR standby database. Once comfortable with the operation of the Db2 copy, the standby can be switched to take on the primary role. This allows for a phased migration of the database and the workloads.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2_HADR.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Reference Information
#        </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This link provide more details on the Db2 Shift program and its various features and options.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="https://ibm.biz/c2cguide">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Reset Examples
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This document will reset the Db2U Kubernetes installation so you can try the lab exercises again!
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Reset.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# <!--    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#FFFFFF; width: 300px; height: 250px;">
#     </td>
# -->
# </table>
# </div>

# %% [markdown]
# #### Credits: IBM 2023, George Baklarz [baklarz@ca.ibm.com], Phil Downey [phil.downey1@ibm.com]
